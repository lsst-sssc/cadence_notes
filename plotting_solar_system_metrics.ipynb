# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Assumes you have the csv files from https://community.lsst.org/t/survey-simulations-v1-7-release-january-2021/4660/3 .
# This notebook is adapted from https://github.com/rhiannonlynne/notebooks/blob/master/Other%20Comparisons.ipynb

# %%
summary = {}
version=['1.5','1.6','1.7']
for r in version:
    summary[r] = pd.read_csv('big_'+r+'.csv', index_col=0)

# %%
baseline=1 # index of the baseline suvery to compare to

# %%
metrics = {}
short_names = {}
styles = {}
metrics['sso'] = ['3 pairs in 15 nights detection loss PHA H=16.0',
               '3 pairs in 15 nights detection loss PHA H=22.0',
               '3 pairs in 15 nights detection loss NEO H=16.0',
               '3 pairs in 15 nights detection loss NEO H=22.0',
               '3 pairs in 15 nights detection loss MBA H=16.0',
               '3 pairs in 15 nights detection loss MBA H=21.0',
               '3 pairs in 15 nights detection loss Trojan H=14.0',
               '3 pairs in 15 nights detection loss Trojan H=18.0',
               '3 pairs in 15 nights detection loss TNO H=6.0',
               '3 pairs in 15 nights detection loss TNO H=8.0',]
short_names['sso'] = ['Completeness PHA H<16.0',
               'Completeness PHA H<22.0',
               'Completeness NEO H<16.0',
               'Completeness NEO H<22.0',
               'Completeness MBA H<16.0',
               'Completeness MBA H<21.0',
               'Completeness Trojan H<14.0',
               'Completeness Trojan H<18.0',
               'Completeness TNO H<6.0',
               'Completeness TNO H<8.0',]
styles['sso'] = ['g-','g--', 'b-', 'b--', 'y-', 'y--', 'c-', 'c--', 'r-', 'r--']

metrics['Lightcurve Inversion'] = ['FractionPop Lightcurve Inversion PHA H=16.0',
 'FractionPop Lightcurve Inversion PHA H=19.0',
 'FractionPop Lightcurve Inversion NEO H=16.0',
 'FractionPop Lightcurve Inversion NEO H=19.0',
 'FractionPop Lightcurve Inversion MBA H=16.0',
 'FractionPop Lightcurve Inversion MBA H=18.0',
 'FractionPop Lightcurve Inversion Trojan H=14.0',
 'FractionPop Lightcurve Inversion Trojan H=15.0']
short_names['Lightcurve Inversion'] = ['Fraction LC Inversion PHA H=16.0',
 'Fraction LC Inversion PHA H=19.0',
 'Fraction LC Inversion NEO H=16.0',
 'Fraction LC Inversion NEO H=19.0',
 'Fraction LC Inversion MBA H=16.0',
 'Fraction LC Inversion MBA H=18.0',
 'Fraction LC Inversion Trojan H=14.0',
 'Fraction LC Inversion Trojan H=15.0']

metrics['Fraction Pop 3 bands'] = ['FractionPop 2 of g, r or i, z or y PHA H=16.0',
                      'FractionPop 2 of g, r or i, z or y PHA H=19.0',
                      'FractionPop 2 of g, r or i, z or y NEO H=16.0',
                      'FractionPop 2 of g, r or i, z or y NEO H=19.0',
                      'FractionPop 2 of g, r or i, z or y MBA H=16.0',
                      'FractionPop 2 of g, r or i, z or y MBA H=18.0',
                      'FractionPop 2 of g, r or i, z or y Trojan H=14.0',
                      'FractionPop 2 of g, r or i, z or y Trojan H=15.0',
                      'FractionPop 3 filters TNO H=6.0',
                      'FractionPop 3 filters TNO H=7.0',]
short_names['Fraction Pop 3 bands'] = ['Fraction 3 of g and (r or i) and (z or y) PHA H=16.0',
                          'Fraction 3 of g and (r or i) and (z or y) PHA H=19.0',
                      'Fraction 3 of g and (r or i) and (z or y) NEO H=16.0',
                      'Fraction 3 of g and (r or i) and (z or y) NEO H=19.0',
                      'Fraction 3 of g and (r or i) and (z or y) MBA H=16.0',
                      'Fraction 3 of g and (r or i) and (z or y) MBA H=18.0',
                      'Fraction 3 of g and (r or i) and (z or y) Trojan H=14.0',
                      'Fraction 3 of g and (r or i) and (z or y) Trojan H=15.0',
                      'Fraction 3 filters TNO H=6.0',
                      'Fraction 3 filters TNO H=7.0',]


metrics['Fraction Pop 4 bands'] = ['FractionPop 4 of grizy PHA H=16.0',
                      'FractionPop 4 of grizy PHA H=19.0',
                      'FractionPop 4 of grizy NEO H=16.0',
                      'FractionPop 4 of grizy NEO H=19.0',
                      'FractionPop 4 of grizy MBA H=16.0',
                      'FractionPop 4 of grizy MBA H=18.0',
                      'FractionPop 4 of grizy Trojan H=14.0',
                      'FractionPop 4 of grizy Trojan H=15.0',
                      'FractionPop 4 filters TNO H=6.0',
                      'FractionPop 4 filters TNO H=7.0',]
short_names['Fraction Pop 4 bands'] = ['Fraction 4 of grizy PHA H=16.0',
                          'Fraction 4 of grizy PHA H=19.0',
                      'Fraction 4 of grizy NEO H=16.0',
                      'Fraction 4 of grizy NEO H=19.0',
                      'Fraction 4 of grizy MBA H=16.0',
                      'Fraction 4 of grizy MBA H=18.0',
                      'Fraction 4 of grizy Trojan H=14.0',
                      'Fraction 4 of grizy Trojan H=15.0',
                      'Fraction 4 filters TNO H=6.0',
                      'Fraction 4 filters TNO H=7.0',]


metrics['Fraction Pop 5 bands'] = ['FractionPop 5 of grizy PHA H=16.0',
                      'FractionPop 5 of grizy PHA H=19.0',
                      'FractionPop 5 of grizy NEO H=16.0',
                      'FractionPop 5 of grizy NEO H=19.0',
                      'FractionPop 5 of grizy MBA H=16.0',
                      'FractionPop 5 of grizy MBA H=18.0',
                      'FractionPop 5 of grizy Trojan H=14.0',
                      'FractionPop 5 of grizy Trojan H=15.0',
                      'FractionPop 5 filters TNO H=6.0',
                      'FractionPop 5 filters TNO H=7.0',]
short_names['Fraction Pop 5 bands'] = ['Fraction with grizy PHA H=16.0',
                          'Fraction with grizy PHA H=19.0',
                      'Fraction with grizy NEO H=16.0',
                      'Fraction with grizy NEO H=19.0',
                      'Fraction with grizy MBA H=16.0',
                      'Fraction with grizy MBA H=18.0',
                      'Fraction with grizy Trojan H=14.0',
                      'Fraction with grizy Trojan H=15.0',
                      'Fraction with 5 filters TNO H=6.0',
                      'Fraction with 5 filters TNO H=7.0',]

metrics['Fraction Pop 6 bands'] = ['FractionPop 6 of ugrizy PHA H=16.0',
 'FractionPop 6 of ugrizy PHA H=19.0',
 'FractionPop 6 of ugrizy NEO H=16.0',
 'FractionPop 6 of ugrizy NEO H=19.0',
 'FractionPop 6 of ugrizy MBA H=16.0',
 'FractionPop 6 of ugrizy MBA H=18.0',
 'FractionPop 6 of ugrizy Trojan H=14.0',
 'FractionPop 6 of ugrizy Trojan H=15.0',
 'FractionPop 6 filters TNO H=6.0',
 'FractionPop 6 filters TNO H=7.0']
short_names['Fraction Pop 6 bands'] = ['Fraction with ugrizy PHA H=16.0',
                          'Fraction with ugrizy PHA H=19.0',
                      'Fraction with ugrizy NEO H=16.0',
                      'Fraction with ugrizy NEO H=19.0',
                      'Fraction with ugrizy MBA H=16.0',
                      'Fraction with ugrizy MBA H=18.0',
                      'Fraction with ugrizy Trojan H=14.0',
                      'Fraction with ugrizy Trojan H=15.0',
                      'Fraction with 6 filters TNO H=6.0',
                      'Fraction with 6 filters TNO H=7.0',]
styles['ssochar'] = ['g-','g--', 'b-', 'b--', 'y-', 'y--', 'c-', 'c--', 'r-', 'r--']

# %%
cols = metrics['sso']
cols_lc=metrics['Lightcurve Inversion']
number_of_sims_per_plot=9

#plot the discovery metrics 
for r in version:
    print(r)
    S =summary[r][cols] / summary['1.7'][cols].iloc[baseline] 
    S.columns = short_names['sso']
    T =summary[r][cols_lcs] / summary['1.7'][cols_lc].iloc[baseline] 
    T.columns = short_names['Lightcurve Inversion']
    startindex=0
    endindex=number_of_sims_per_plot

    for i in np.arange(int(np.round(len(S)/np.float(number_of_sims_per_plot)+0.5)), dtype=int):
        # plot detection fractions
        D=S[startindex:endindex]
        startindex=endindex+1
        if (endindex+number_of_sims_per_plot>len(S)):
            endindex=len(S)
        else:
            endindex=endindex+number_of_sims_per_plot-1

        xi = np.arange(len(D))
    
        xnames = D.index.values
        D.plot(figsize=(20, 9), style=styles['sso'])
        plt.legend(loc=(1, 0.05))
        plt.xticks(xi, xnames, rotation=90, fontsize='large')
        plt.title('Discovery Variation (%)')
        plt.grid(True, alpha=0.3, color='k', linestyle=':')
        plt.tight_layout()
        plt.savefig('discovery_completeness_all_v'+str(r)+'_'+str(np.int(i))+'.pdf')
        plt.close('all')
        
     # plot lc metics 
    
    startindex=0
    endindex=number_of_sims_per_plot
    
    for i in np.arange(int(np.round(len(T)/np.float(number_of_sims_per_plot)+0.5)), dtype=int):
        # plot detection fractions
        D=T[startindex:endindex]
        startindex=endindex+1
        if (endindex+number_of_sims_per_plot>len(T)):
            endindex=len(T)
        else:
            endindex=endindex+number_of_sims_per_plot-1

        xi = np.arange(len(D))
    
        xnames = D.index.values
        D.plot(figsize=(20, 9), style=styles['sso'])
        plt.legend(loc=(1, 0.05))
        plt.xticks(xi, xnames, rotation=90, fontsize='large')
        plt.title('Discovery Variation (%)')
        plt.grid(True, alpha=0.3, color='k', linestyle=':')
        plt.tight_layout()
        plt.savefig('light_curve_inversion_all_v'+str(r)+'_'+str(np.int(i))+'.pdf')
        plt.close('all')
# Out:
# 1.5
# 1.6
# 1.7

# %%
for k in summary['1.7'].index.values:  # get list of simulations from v1.7
    print(k)
# Out:
# baseline_nexp1_v1.7_10yrs
# baseline_nexp2_v1.7_10yrs
# cadence_drive_gl100_gcbv1.7_10yrs
# cadence_drive_gl100v1.7_10yrs
# cadence_drive_gl200_gcbv1.7_10yrs
# cadence_drive_gl200v1.7_10yrs
# cadence_drive_gl30_gcbv1.7_10yrs
# cadence_drive_gl30v1.7_10yrs
# ddf_dither0.00_v1.7_10yrs
# ddf_dither0.05_v1.7_10yrs
# ddf_dither0.10_v1.7_10yrs
# ddf_dither0.30_v1.7_10yrs
# ddf_dither0.70_v1.7_10yrs
# ddf_dither1.00_v1.7_10yrs
# ddf_dither1.50_v1.7_10yrs
# ddf_dither2.00_v1.7_10yrs
# euclid_dither1_v1.7_10yrs
# euclid_dither2_v1.7_10yrs
# euclid_dither3_v1.7_10yrs
# euclid_dither4_v1.7_10yrs
# euclid_dither5_v1.7_10yrs
# footprint_0_v1.710yrs
# footprint_1_v1.710yrs
# footprint_2_v1.710yrs
# footprint_3_v1.710yrs
# footprint_4_v1.710yrs
# footprint_5_v1.710yrs
# footprint_6_v1.710yrs
# footprint_7_v1.710yrs
# footprint_8_v1.710yrs
# pair_times_11_v1.7_10yrs
# pair_times_22_v1.7_10yrs
# pair_times_33_v1.7_10yrs
# pair_times_44_v1.7_10yrs
# pair_times_55_v1.7_10yrs
# rolling_nm_scale0.2_nslice2_v1.7_10yrs
# rolling_nm_scale0.2_nslice3_v1.7_10yrs
# rolling_nm_scale0.4_nslice2_v1.7_10yrs
# rolling_nm_scale0.4_nslice3_v1.7_10yrs
# rolling_nm_scale0.6_nslice2_v1.7_10yrs
# rolling_nm_scale0.6_nslice3_v1.7_10yrs
# rolling_nm_scale0.8_nslice2_v1.7_10yrs
# rolling_nm_scale0.8_nslice3_v1.7_10yrs
# rolling_nm_scale0.9_nslice2_v1.7_10yrs
# rolling_nm_scale0.9_nslice3_v1.7_10yrs
# rolling_nm_scale1.0_nslice2_v1.7_10yrs
# rolling_nm_scale1.0_nslice3_v1.7_10yrs
# rolling_scale0.2_nslice2_v1.7_10yrs
# rolling_scale0.2_nslice3_v1.7_10yrs
# rolling_scale0.4_nslice2_v1.7_10yrs
# rolling_scale0.4_nslice3_v1.7_10yrs
# rolling_scale0.6_nslice2_v1.7_10yrs
# rolling_scale0.6_nslice3_v1.7_10yrs
# rolling_scale0.8_nslice2_v1.7_10yrs
# rolling_scale0.8_nslice3_v1.7_10yrs
# rolling_scale0.9_nslice2_v1.7_10yrs
# rolling_scale0.9_nslice3_v1.7_10yrs
# rolling_scale1.0_nslice2_v1.7_10yrs
# rolling_scale1.0_nslice3_v1.7_10yrs
# twi_neo_pattern1_v1.7_10yrs
# twi_neo_pattern2_v1.7_10yrs
# twi_neo_pattern3_v1.7_10yrs
# twi_neo_pattern4_v1.7_10yrs
# twi_neo_pattern5_v1.7_10yrs
# twi_neo_pattern6_v1.7_10yrs
# twi_neo_pattern7_v1.7_10yrs
# u_long_ms_50_v1.7_10yrs
# twi_pairs_mixed_repeat_v1.7_10yrs
# u_long_ms_30_v1.7_10yrs
# u_long_ms_40_v1.7_10yrs
# u_long_ms_60_v1.7_10yrs
# twi_pairs_mixed_v1.7_10yrs
# twi_pairs_repeat_v1.7_10yrs
# twi_pairs_v1.7_10yrs

# %%
list(summary['1.7'].columns.values) # get list of metrics from v1.7
# Out:
# ['fOArea fO All visits HealpixSlicer',
#  'fOArea/benchmark fO All visits HealpixSlicer',
#  'fONv MedianNvis fO All visits HealpixSlicer',
#  'fONv MinNvis fO All visits HealpixSlicer',
#  'fONv/benchmark MedianNvis fO All visits HealpixSlicer',
#  'fONv/benchmark MinNvis fO All visits HealpixSlicer',
#  'Median Parallax Error (18k) Parallax Error @ 22.4 All visits HealpixSlicer',
#  '95th Percentile Parallax Error Parallax Error @ 22.4 All visits HealpixSlicer',
#  'Mean Parallax Error @ 22.4 All visits HealpixSlicer',
#  'Rms Parallax Error @ 22.4 All visits HealpixSlicer',
#  'Median Parallax Error @ 22.4 All visits HealpixSlicer',
#  'Max Parallax Error @ 22.4 All visits HealpixSlicer',
#  'Min Parallax Error @ 22.4 All visits HealpixSlicer',
#  'N(+3Sigma) Parallax Error @ 22.4 All visits HealpixSlicer',
#  'N(-3Sigma) Parallax Error @ 22.4 All visits HealpixSlicer',
#  'Parallax Error @ 22.4 All visits HealpixSlicer',
#  'Median Parallax Error (18k) Parallax Error @ 24.0 All visits HealpixSlicer',
#  '95th Percentile Parallax Error Parallax Error @ 24.0 All visits HealpixSlicer',
#  'Mean Parallax Error @ 24.0 All visits HealpixSlicer',
#  'Rms Parallax Error @ 24.0 All visits HealpixSlicer',
#  'Median Parallax Error @ 24.0 All visits HealpixSlicer',
#  'Max Parallax Error @ 24.0 All visits HealpixSlicer',
#  'Min Parallax Error @ 24.0 All visits HealpixSlicer',
#  'N(+3Sigma) Parallax Error @ 24.0 All visits HealpixSlicer',
#  'N(-3Sigma) Parallax Error @ 24.0 All visits HealpixSlicer',
#  'Parallax Error @ 24.0 All visits HealpixSlicer',
#  'Mean Normalized Parallax @ 22.4 All visits HealpixSlicer',
#  'Rms Normalized Parallax @ 22.4 All visits HealpixSlicer',
#  'Median Normalized Parallax @ 22.4 All visits HealpixSlicer',
#  'Max Normalized Parallax @ 22.4 All visits HealpixSlicer',
#  'Min Normalized Parallax @ 22.4 All visits HealpixSlicer',
#  'N(+3Sigma) Normalized Parallax @ 22.4 All visits HealpixSlicer',
#  'N(-3Sigma) Normalized Parallax @ 22.4 All visits HealpixSlicer',
#  'Normalized Parallax @ 22.4 All visits HealpixSlicer',
#  'Mean Normalized Parallax @ 24.0 All visits HealpixSlicer',
#  'Rms Normalized Parallax @ 24.0 All visits HealpixSlicer',
#  'Median Normalized Parallax @ 24.0 All visits HealpixSlicer',
#  'Max Normalized Parallax @ 24.0 All visits HealpixSlicer',
#  'Min Normalized Parallax @ 24.0 All visits HealpixSlicer',
#  'N(+3Sigma) Normalized Parallax @ 24.0 All visits HealpixSlicer',
#  'N(-3Sigma) Normalized Parallax @ 24.0 All visits HealpixSlicer',
#  'Normalized Parallax @ 24.0 All visits HealpixSlicer',
#  'Mean Parallax Coverage @ 22.4 All visits HealpixSlicer',
#  'Rms Parallax Coverage @ 22.4 All visits HealpixSlicer',
#  'Median Parallax Coverage @ 22.4 All visits HealpixSlicer',
#  'Max Parallax Coverage @ 22.4 All visits HealpixSlicer',
#  'Min Parallax Coverage @ 22.4 All visits HealpixSlicer',
#  'N(+3Sigma) Parallax Coverage @ 22.4 All visits HealpixSlicer',
#  'N(-3Sigma) Parallax Coverage @ 22.4 All visits HealpixSlicer',
#  'Parallax Coverage @ 22.4 All visits HealpixSlicer',
#  'Mean Parallax Coverage @ 24.0 All visits HealpixSlicer',
#  'Rms Parallax Coverage @ 24.0 All visits HealpixSlicer',
#  'Median Parallax Coverage @ 24.0 All visits HealpixSlicer',
#  'Max Parallax Coverage @ 24.0 All visits HealpixSlicer',
#  'Min Parallax Coverage @ 24.0 All visits HealpixSlicer',
#  'N(+3Sigma) Parallax Coverage @ 24.0 All visits HealpixSlicer',
#  'N(-3Sigma) Parallax Coverage @ 24.0 All visits HealpixSlicer',
#  'Parallax Coverage @ 24.0 All visits HealpixSlicer',
#  'Mean Parallax-DCR degeneracy @ 22.4 All visits HealpixSlicer',
#  'Rms Parallax-DCR degeneracy @ 22.4 All visits HealpixSlicer',
#  'Median Parallax-DCR degeneracy @ 22.4 All visits HealpixSlicer',
#  'Max Parallax-DCR degeneracy @ 22.4 All visits HealpixSlicer',
#  'Min Parallax-DCR degeneracy @ 22.4 All visits HealpixSlicer',
#  'N(+3Sigma) Parallax-DCR degeneracy @ 22.4 All visits HealpixSlicer',
#  'N(-3Sigma) Parallax-DCR degeneracy @ 22.4 All visits HealpixSlicer',
#  'Parallax-DCR degeneracy @ 22.4 All visits HealpixSlicer',
#  'Mean Parallax-DCR degeneracy @ 24.0 All visits HealpixSlicer',
#  'Rms Parallax-DCR degeneracy @ 24.0 All visits HealpixSlicer',
#  'Median Parallax-DCR degeneracy @ 24.0 All visits HealpixSlicer',
#  'Max Parallax-DCR degeneracy @ 24.0 All visits HealpixSlicer',
#  'Min Parallax-DCR degeneracy @ 24.0 All visits HealpixSlicer',
#  'N(+3Sigma) Parallax-DCR degeneracy @ 24.0 All visits HealpixSlicer',
#  'N(-3Sigma) Parallax-DCR degeneracy @ 24.0 All visits HealpixSlicer',
#  'Parallax-DCR degeneracy @ 24.0 All visits HealpixSlicer',
#  'Median Proper Motion Error (18k) Proper Motion Error @ 20.5 All visits HealpixSlicer',
#  '95th Percentile Proper Motion Error Proper Motion Error @ 20.5 All visits HealpixSlicer',
#  'Mean Proper Motion Error @ 20.5 All visits HealpixSlicer',
#  'Rms Proper Motion Error @ 20.5 All visits HealpixSlicer',
#  'Median Proper Motion Error @ 20.5 All visits HealpixSlicer',
#  'Max Proper Motion Error @ 20.5 All visits HealpixSlicer',
#  'Min Proper Motion Error @ 20.5 All visits HealpixSlicer',
#  'N(+3Sigma) Proper Motion Error @ 20.5 All visits HealpixSlicer',
#  'N(-3Sigma) Proper Motion Error @ 20.5 All visits HealpixSlicer',
#  'Proper Motion Error @ 20.5 All visits HealpixSlicer',
#  'Median Proper Motion Error (18k) Proper Motion Error @ 24.0 All visits HealpixSlicer',
#  '95th Percentile Proper Motion Error Proper Motion Error @ 24.0 All visits HealpixSlicer',
#  'Mean Proper Motion Error @ 24.0 All visits HealpixSlicer',
#  'Rms Proper Motion Error @ 24.0 All visits HealpixSlicer',
#  'Median Proper Motion Error @ 24.0 All visits HealpixSlicer',
#  'Max Proper Motion Error @ 24.0 All visits HealpixSlicer',
#  'Min Proper Motion Error @ 24.0 All visits HealpixSlicer',
#  'N(+3Sigma) Proper Motion Error @ 24.0 All visits HealpixSlicer',
#  'N(-3Sigma) Proper Motion Error @ 24.0 All visits HealpixSlicer',
#  'Proper Motion Error @ 24.0 All visits HealpixSlicer',
#  'Mean Normalized Proper Motion @ 20.5 All visits HealpixSlicer',
#  'Rms Normalized Proper Motion @ 20.5 All visits HealpixSlicer',
#  'Median Normalized Proper Motion @ 20.5 All visits HealpixSlicer',
#  'Max Normalized Proper Motion @ 20.5 All visits HealpixSlicer',
#  'Min Normalized Proper Motion @ 20.5 All visits HealpixSlicer',
#  'N(+3Sigma) Normalized Proper Motion @ 20.5 All visits HealpixSlicer',
#  'N(-3Sigma) Normalized Proper Motion @ 20.5 All visits HealpixSlicer',
#  'Normalized Proper Motion @ 20.5 All visits HealpixSlicer',
#  'Mean Normalized Proper Motion @ 24.0 All visits HealpixSlicer',
#  'Rms Normalized Proper Motion @ 24.0 All visits HealpixSlicer',
#  'Median Normalized Proper Motion @ 24.0 All visits HealpixSlicer',
#  'Max Normalized Proper Motion @ 24.0 All visits HealpixSlicer',
#  'Min Normalized Proper Motion @ 24.0 All visits HealpixSlicer',
#  'N(+3Sigma) Normalized Proper Motion @ 24.0 All visits HealpixSlicer',
#  'N(-3Sigma) Normalized Proper Motion @ 24.0 All visits HealpixSlicer',
#  'Normalized Proper Motion @ 24.0 All visits HealpixSlicer',
#  'Mean NumberOfQuickRevisits All visits HealpixSlicer',
#  'Rms NumberOfQuickRevisits All visits HealpixSlicer',
#  'Median NumberOfQuickRevisits All visits HealpixSlicer',
#  'Max NumberOfQuickRevisits All visits HealpixSlicer',
#  'Min NumberOfQuickRevisits All visits HealpixSlicer',
#  'N(+3Sigma) NumberOfQuickRevisits All visits HealpixSlicer',
#  'N(-3Sigma) NumberOfQuickRevisits All visits HealpixSlicer',
#  'RapidRevisits All visits HealpixSlicer',
#  'Mean PeriodDetection P_0.5_Mag_21_Amp_0.05-0.1-1 HealpixSlicer',
#  'Rms PeriodDetection P_0.5_Mag_21_Amp_0.05-0.1-1 HealpixSlicer',
#  'Median PeriodDetection P_0.5_Mag_21_Amp_0.05-0.1-1 HealpixSlicer',
#  'Max PeriodDetection P_0.5_Mag_21_Amp_0.05-0.1-1 HealpixSlicer',
#  'Min PeriodDetection P_0.5_Mag_21_Amp_0.05-0.1-1 HealpixSlicer',
#  'N(+3Sigma) PeriodDetection P_0.5_Mag_21_Amp_0.05-0.1-1 HealpixSlicer',
#  'N(-3Sigma) PeriodDetection P_0.5_Mag_21_Amp_0.05-0.1-1 HealpixSlicer',
#  'Mean PeriodDetection P_0.5_Mag_24_Amp_0.05-0.1-1 HealpixSlicer',
#  'Rms PeriodDetection P_0.5_Mag_24_Amp_0.05-0.1-1 HealpixSlicer',
#  'Median PeriodDetection P_0.5_Mag_24_Amp_0.05-0.1-1 HealpixSlicer',
#  'Max PeriodDetection P_0.5_Mag_24_Amp_0.05-0.1-1 HealpixSlicer',
#  'Min PeriodDetection P_0.5_Mag_24_Amp_0.05-0.1-1 HealpixSlicer',
#  'N(+3Sigma) PeriodDetection P_0.5_Mag_24_Amp_0.05-0.1-1 HealpixSlicer',
#  'N(-3Sigma) PeriodDetection P_0.5_Mag_24_Amp_0.05-0.1-1 HealpixSlicer',
#  'Mean PeriodDetection P_1.0_Mag_21_Amp_0.05-0.1-1 HealpixSlicer',
#  'Rms PeriodDetection P_1.0_Mag_21_Amp_0.05-0.1-1 HealpixSlicer',
#  'Median PeriodDetection P_1.0_Mag_21_Amp_0.05-0.1-1 HealpixSlicer',
#  'Max PeriodDetection P_1.0_Mag_21_Amp_0.05-0.1-1 HealpixSlicer',
#  'Min PeriodDetection P_1.0_Mag_21_Amp_0.05-0.1-1 HealpixSlicer',
#  'N(+3Sigma) PeriodDetection P_1.0_Mag_21_Amp_0.05-0.1-1 HealpixSlicer',
#  'N(-3Sigma) PeriodDetection P_1.0_Mag_21_Amp_0.05-0.1-1 HealpixSlicer',
#  'Mean PeriodDetection P_1.0_Mag_24_Amp_0.05-0.1-1 HealpixSlicer',
#  'Rms PeriodDetection P_1.0_Mag_24_Amp_0.05-0.1-1 HealpixSlicer',
#  'Median PeriodDetection P_1.0_Mag_24_Amp_0.05-0.1-1 HealpixSlicer',
#  'Max PeriodDetection P_1.0_Mag_24_Amp_0.05-0.1-1 HealpixSlicer',
#  'Min PeriodDetection P_1.0_Mag_24_Amp_0.05-0.1-1 HealpixSlicer',
#  'N(+3Sigma) PeriodDetection P_1.0_Mag_24_Amp_0.05-0.1-1 HealpixSlicer',
#  'N(-3Sigma) PeriodDetection P_1.0_Mag_24_Amp_0.05-0.1-1 HealpixSlicer',
#  'Mean PeriodDetection P_2.0_Mag_21_Amp_0.05-0.1-1 HealpixSlicer',
#  'Rms PeriodDetection P_2.0_Mag_21_Amp_0.05-0.1-1 HealpixSlicer',
#  'Median PeriodDetection P_2.0_Mag_21_Amp_0.05-0.1-1 HealpixSlicer',
#  'Max PeriodDetection P_2.0_Mag_21_Amp_0.05-0.1-1 HealpixSlicer',
#  'Min PeriodDetection P_2.0_Mag_21_Amp_0.05-0.1-1 HealpixSlicer',
#  'N(+3Sigma) PeriodDetection P_2.0_Mag_21_Amp_0.05-0.1-1 HealpixSlicer',
#  'N(-3Sigma) PeriodDetection P_2.0_Mag_21_Amp_0.05-0.1-1 HealpixSlicer',
#  'Mean PeriodDetection P_2.0_Mag_24_Amp_0.05-0.1-1 HealpixSlicer',
#  'Rms PeriodDetection P_2.0_Mag_24_Amp_0.05-0.1-1 HealpixSlicer',
#  'Median PeriodDetection P_2.0_Mag_24_Amp_0.05-0.1-1 HealpixSlicer',
#  'Max PeriodDetection P_2.0_Mag_24_Amp_0.05-0.1-1 HealpixSlicer',
#  'Min PeriodDetection P_2.0_Mag_24_Amp_0.05-0.1-1 HealpixSlicer',
#  'N(+3Sigma) PeriodDetection P_2.0_Mag_24_Amp_0.05-0.1-1 HealpixSlicer',
#  'N(-3Sigma) PeriodDetection P_2.0_Mag_24_Amp_0.05-0.1-1 HealpixSlicer',
#  'Fast Microlensing  UserPointsSlicer',
#  'Slow Microlensing  UserPointsSlicer',
#  'KN_Detected  UserPointsSlicer',
#  'KN_Nobs  UserPointsSlicer',
#  'KN_PrePeak  UserPointsSlicer',
#  'KN_WellSampled  UserPointsSlicer',
#  'TDEsPopMetric__prepeak  UserPointsSlicer',
#  'TDEsPopMetric__some_color  UserPointsSlicer',
#  'TDEsPopMetric__some_color_pu  UserPointsSlicer',
#  'DD:ELAISS1 SNIa_Detected  UserPointsSlicer',
#  'DD:ELAISS1 SNIa_Nobs  UserPointsSlicer',
#  'DD:ELAISS1 SNIa_PrePeak  UserPointsSlicer',
#  'DD:ELAISS1 SNIa_WellSampled  UserPointsSlicer',
#  'DD:XMM-LSS SNIa_Detected  UserPointsSlicer',
#  'DD:XMM-LSS SNIa_Nobs  UserPointsSlicer',
#  'DD:XMM-LSS SNIa_PrePeak  UserPointsSlicer',
#  'DD:XMM-LSS SNIa_WellSampled  UserPointsSlicer',
#  'DD:ECDFS SNIa_Detected  UserPointsSlicer',
#  'DD:ECDFS SNIa_Nobs  UserPointsSlicer',
#  'DD:ECDFS SNIa_PrePeak  UserPointsSlicer',
#  'DD:ECDFS SNIa_WellSampled  UserPointsSlicer',
#  'DD:COSMOS SNIa_Detected  UserPointsSlicer',
#  'DD:COSMOS SNIa_Nobs  UserPointsSlicer',
#  'DD:COSMOS SNIa_PrePeak  UserPointsSlicer',
#  'DD:COSMOS SNIa_WellSampled  UserPointsSlicer',
#  'DD:EDFS SNIa_Detected  UserPointsSlicer',
#  'DD:EDFS SNIa_Nobs  UserPointsSlicer',
#  'DD:EDFS SNIa_PrePeak  UserPointsSlicer',
#  'DD:EDFS SNIa_WellSampled  UserPointsSlicer',
#  'DD:EDFSa SNIa_Detected  UserPointsSlicer',
#  'DD:EDFSa SNIa_Nobs  UserPointsSlicer',
#  'DD:EDFSa SNIa_PrePeak  UserPointsSlicer',
#  'DD:EDFSa SNIa_WellSampled  UserPointsSlicer',
#  'DD:EDFSb SNIa_Detected  UserPointsSlicer',
#  'DD:EDFSb SNIa_Nobs  UserPointsSlicer',
#  'DD:EDFSb SNIa_PrePeak  UserPointsSlicer',
#  'DD:EDFSb SNIa_WellSampled  UserPointsSlicer',
#  'Mean ExgalM5_with_cuts i band non-DD year 10 HealpixSlicer',
#  'Median ExgalM5_with_cuts i band non-DD year 10 HealpixSlicer',
#  'Rms ExgalM5_with_cuts i band non-DD year 10 HealpixSlicer',
#  'Effective Area (deg) ExgalM5_with_cuts i band non-DD year 10 HealpixSlicer',
#  '3x2ptFoM ExgalM5_with_cuts i band non-DD year 10 HealpixSlicer',
#  'YearCoverage night i band HealpixSlicer',
#  'Mean Kuiper rotSkyPos  i HealpixSlicer',
#  'Rms Kuiper rotSkyPos  i HealpixSlicer',
#  'Median Kuiper rotSkyPos  i HealpixSlicer',
#  'Max Kuiper rotSkyPos  i HealpixSlicer',
#  'Min Kuiper rotSkyPos  i HealpixSlicer',
#  'N(+3Sigma) Kuiper rotSkyPos  i HealpixSlicer',
#  'N(-3Sigma) Kuiper rotSkyPos  i HealpixSlicer',
#  'Mean Kuiper rotTelPos  i HealpixSlicer',
#  'Rms Kuiper rotTelPos  i HealpixSlicer',
#  'Median Kuiper rotTelPos  i HealpixSlicer',
#  'Max Kuiper rotTelPos  i HealpixSlicer',
#  'Min Kuiper rotTelPos  i HealpixSlicer',
#  'N(+3Sigma) Kuiper rotTelPos  i HealpixSlicer',
#  'N(-3Sigma) Kuiper rotTelPos  i HealpixSlicer',
#  'N stars to Precision 0.20  i HealpixSlicer',
#  'Nstars_no_crowding  i HealpixSlicer',
#  'DD:ELAISS1, i i band UserPointsSlicer',
#  'DD:XMM-LSS, i i band UserPointsSlicer',
#  'DD:ECDFS, i i band UserPointsSlicer',
#  'DD:COSMOS, i i band UserPointsSlicer',
#  'DD:EDFS, i i band UserPointsSlicer',
#  'DD:EDFSa, i i band UserPointsSlicer',
#  'DD:EDFSb, i i band UserPointsSlicer',
#  'YearCoverage night u band HealpixSlicer',
#  'Mean Kuiper rotSkyPos  u HealpixSlicer',
#  'Rms Kuiper rotSkyPos  u HealpixSlicer',
#  'Median Kuiper rotSkyPos  u HealpixSlicer',
#  'Max Kuiper rotSkyPos  u HealpixSlicer',
#  'Min Kuiper rotSkyPos  u HealpixSlicer',
#  'N(+3Sigma) Kuiper rotSkyPos  u HealpixSlicer',
#  'N(-3Sigma) Kuiper rotSkyPos  u HealpixSlicer',
#  'Mean Kuiper rotTelPos  u HealpixSlicer',
#  'Rms Kuiper rotTelPos  u HealpixSlicer',
#  'Median Kuiper rotTelPos  u HealpixSlicer',
#  'Max Kuiper rotTelPos  u HealpixSlicer',
#  'Min Kuiper rotTelPos  u HealpixSlicer',
#  'N(+3Sigma) Kuiper rotTelPos  u HealpixSlicer',
#  'N(-3Sigma) Kuiper rotTelPos  u HealpixSlicer',
#  'N stars to Precision 0.20  u HealpixSlicer',
#  'Nstars_no_crowding  u HealpixSlicer',
#  'DD:ELAISS1, u u band UserPointsSlicer',
#  'DD:XMM-LSS, u u band UserPointsSlicer',
#  'DD:ECDFS, u u band UserPointsSlicer',
#  'DD:COSMOS, u u band UserPointsSlicer',
#  'DD:EDFS, u u band UserPointsSlicer',
#  'DD:EDFSa, u u band UserPointsSlicer',
#  'DD:EDFSb, u u band UserPointsSlicer',
#  'Mean ExgalM5_with_cuts i band non-DD year 1 HealpixSlicer',
#  'Median ExgalM5_with_cuts i band non-DD year 1 HealpixSlicer',
#  'Rms ExgalM5_with_cuts i band non-DD year 1 HealpixSlicer',
#  'Effective Area (deg) ExgalM5_with_cuts i band non-DD year 1 HealpixSlicer',
#  '3x2ptFoM ExgalM5_with_cuts i band non-DD year 1 HealpixSlicer',
#  'Mean WeakLensingNvisits fiveSigmaDepth, visitExposureTime i band non-DD HealpixSlicer',
#  'Rms WeakLensingNvisits fiveSigmaDepth, visitExposureTime i band non-DD HealpixSlicer',
#  'Median WeakLensingNvisits fiveSigmaDepth, visitExposureTime i band non-DD HealpixSlicer',
#  'Max WeakLensingNvisits fiveSigmaDepth, visitExposureTime i band non-DD HealpixSlicer',
#  'Min WeakLensingNvisits fiveSigmaDepth, visitExposureTime i band non-DD HealpixSlicer',
#  'N(+3Sigma) WeakLensingNvisits fiveSigmaDepth, visitExposureTime i band non-DD HealpixSlicer',
#  'N(-3Sigma) WeakLensingNvisits fiveSigmaDepth, visitExposureTime i band non-DD HealpixSlicer',
#  'YearCoverage night g band HealpixSlicer',
#  'Mean Kuiper rotSkyPos  g HealpixSlicer',
#  'Rms Kuiper rotSkyPos  g HealpixSlicer',
#  'Median Kuiper rotSkyPos  g HealpixSlicer',
#  'Max Kuiper rotSkyPos  g HealpixSlicer',
#  'Min Kuiper rotSkyPos  g HealpixSlicer',
#  'N(+3Sigma) Kuiper rotSkyPos  g HealpixSlicer',
#  'N(-3Sigma) Kuiper rotSkyPos  g HealpixSlicer',
#  'Mean Kuiper rotTelPos  g HealpixSlicer',
#  'Rms Kuiper rotTelPos  g HealpixSlicer',
#  'Median Kuiper rotTelPos  g HealpixSlicer',
#  'Max Kuiper rotTelPos  g HealpixSlicer',
#  'Min Kuiper rotTelPos  g HealpixSlicer',
#  'N(+3Sigma) Kuiper rotTelPos  g HealpixSlicer',
#  'N(-3Sigma) Kuiper rotTelPos  g HealpixSlicer',
#  'N stars to Precision 0.20  g HealpixSlicer',
#  'Nstars_no_crowding  g HealpixSlicer',
#  'DD:ELAISS1, g g band UserPointsSlicer',
#  'DD:XMM-LSS, g g band UserPointsSlicer',
#  'DD:ECDFS, g g band UserPointsSlicer',
#  'DD:COSMOS, g g band UserPointsSlicer',
#  'DD:EDFS, g g band UserPointsSlicer',
#  'DD:EDFSa, g g band UserPointsSlicer',
#  'DD:EDFSb, g g band UserPointsSlicer',
#  'N Galaxies (18k) GalaxyCountsMetric_extended i band HealpixSlicer',
#  'N Galaxies (all) GalaxyCountsMetric_extended i band HealpixSlicer',
#  'Mean ExgalM5_with_cuts i band non-DD year 3 HealpixSlicer',
#  'Median ExgalM5_with_cuts i band non-DD year 3 HealpixSlicer',
#  'Rms ExgalM5_with_cuts i band non-DD year 3 HealpixSlicer',
#  'Effective Area (deg) ExgalM5_with_cuts i band non-DD year 3 HealpixSlicer',
#  '3x2ptFoM ExgalM5_with_cuts i band non-DD year 3 HealpixSlicer',
#  'YearCoverage night z band HealpixSlicer',
#  'Mean Kuiper rotSkyPos  z HealpixSlicer',
#  'Rms Kuiper rotSkyPos  z HealpixSlicer',
#  'Median Kuiper rotSkyPos  z HealpixSlicer',
#  'Max Kuiper rotSkyPos  z HealpixSlicer',
#  'Min Kuiper rotSkyPos  z HealpixSlicer',
#  'N(+3Sigma) Kuiper rotSkyPos  z HealpixSlicer',
#  'N(-3Sigma) Kuiper rotSkyPos  z HealpixSlicer',
#  'Mean Kuiper rotTelPos  z HealpixSlicer',
#  'Rms Kuiper rotTelPos  z HealpixSlicer',
#  'Median Kuiper rotTelPos  z HealpixSlicer',
#  'Max Kuiper rotTelPos  z HealpixSlicer',
#  'Min Kuiper rotTelPos  z HealpixSlicer',
#  'N(+3Sigma) Kuiper rotTelPos  z HealpixSlicer',
#  'N(-3Sigma) Kuiper rotTelPos  z HealpixSlicer',
#  'N stars to Precision 0.20  z HealpixSlicer',
#  'Nstars_no_crowding  z HealpixSlicer',
#  'DD:ELAISS1, z z band UserPointsSlicer',
#  'DD:XMM-LSS, z z band UserPointsSlicer',
#  'DD:ECDFS, z z band UserPointsSlicer',
#  'DD:COSMOS, z z band UserPointsSlicer',
#  'DD:EDFS, z z band UserPointsSlicer',
#  'DD:EDFSa, z z band UserPointsSlicer',
#  'DD:EDFSb, z z band UserPointsSlicer',
#  'N Galaxies (18k) DepthLimitedNumGalaxiesMetric i band galaxies non-DD HealpixSlicer',
#  'N Galaxies (all) DepthLimitedNumGalaxiesMetric i band galaxies non-DD HealpixSlicer',
#  'SNIa_Detected non-DD UserPointsSlicer',
#  'SNIa_Nobs non-DD UserPointsSlicer',
#  'SNIa_PrePeak non-DD UserPointsSlicer',
#  'SNIa_WellSampled non-DD UserPointsSlicer',
#  'YearCoverage night r band HealpixSlicer',
#  'Mean Kuiper rotSkyPos  r HealpixSlicer',
#  'Rms Kuiper rotSkyPos  r HealpixSlicer',
#  'Median Kuiper rotSkyPos  r HealpixSlicer',
#  'Max Kuiper rotSkyPos  r HealpixSlicer',
#  'Min Kuiper rotSkyPos  r HealpixSlicer',
#  'N(+3Sigma) Kuiper rotSkyPos  r HealpixSlicer',
#  'N(-3Sigma) Kuiper rotSkyPos  r HealpixSlicer',
#  'Mean Kuiper rotTelPos  r HealpixSlicer',
#  'Rms Kuiper rotTelPos  r HealpixSlicer',
#  'Median Kuiper rotTelPos  r HealpixSlicer',
#  'Max Kuiper rotTelPos  r HealpixSlicer',
#  'Min Kuiper rotTelPos  r HealpixSlicer',
#  'N(+3Sigma) Kuiper rotTelPos  r HealpixSlicer',
#  'N(-3Sigma) Kuiper rotTelPos  r HealpixSlicer',
#  'N stars to Precision 0.20  r HealpixSlicer',
#  'Nstars_no_crowding  r HealpixSlicer',
#  'DD:ELAISS1, r r band UserPointsSlicer',
#  'DD:XMM-LSS, r r band UserPointsSlicer',
#  'DD:ECDFS, r r band UserPointsSlicer',
#  'DD:COSMOS, r r band UserPointsSlicer',
#  'DD:EDFS, r r band UserPointsSlicer',
#  'DD:EDFSa, r r band UserPointsSlicer',
#  'DD:EDFSb, r r band UserPointsSlicer',
#  'Mean ExgalM5_with_cuts i band non-DD year 6 HealpixSlicer',
#  'Median ExgalM5_with_cuts i band non-DD year 6 HealpixSlicer',
#  'Rms ExgalM5_with_cuts i band non-DD year 6 HealpixSlicer',
#  'Effective Area (deg) ExgalM5_with_cuts i band non-DD year 6 HealpixSlicer',
#  '3x2ptFoM ExgalM5_with_cuts i band non-DD year 6 HealpixSlicer',
#  'YearCoverage night y band HealpixSlicer',
#  'Mean Kuiper rotSkyPos  y HealpixSlicer',
#  'Rms Kuiper rotSkyPos  y HealpixSlicer',
#  'Median Kuiper rotSkyPos  y HealpixSlicer',
#  'Max Kuiper rotSkyPos  y HealpixSlicer',
#  'Min Kuiper rotSkyPos  y HealpixSlicer',
#  'N(+3Sigma) Kuiper rotSkyPos  y HealpixSlicer',
#  'N(-3Sigma) Kuiper rotSkyPos  y HealpixSlicer',
#  'Mean Kuiper rotTelPos  y HealpixSlicer',
#  'Rms Kuiper rotTelPos  y HealpixSlicer',
#  'Median Kuiper rotTelPos  y HealpixSlicer',
#  'Max Kuiper rotTelPos  y HealpixSlicer',
#  'Min Kuiper rotTelPos  y HealpixSlicer',
#  'N(+3Sigma) Kuiper rotTelPos  y HealpixSlicer',
#  'N(-3Sigma) Kuiper rotTelPos  y HealpixSlicer',
#  'N stars to Precision 0.20  y HealpixSlicer',
#  'Nstars_no_crowding  y HealpixSlicer',
#  'DD:ELAISS1, y y band UserPointsSlicer',
#  'DD:XMM-LSS, y y band UserPointsSlicer',
#  'DD:ECDFS, y y band UserPointsSlicer',
#  'DD:COSMOS, y y band UserPointsSlicer',
#  'DD:EDFS, y y band UserPointsSlicer',
#  'DD:EDFSa, y y band UserPointsSlicer',
#  'DD:EDFSb, y y band UserPointsSlicer',
#  'high_accuracy_fraction TDC  HealpixSlicer',
#  'high_accuracy_area TDC  HealpixSlicer',
#  'total_area TDC  HealpixSlicer',
#  'hA_cadence TDC  HealpixSlicer',
#  'hA_season TDC  HealpixSlicer',
#  'hA_campaign TDC  HealpixSlicer',
#  'precision_per_lens TDC  HealpixSlicer',
#  'hA_rate TDC  HealpixSlicer',
#  'N_lenses TDC  HealpixSlicer',
#  'distance_precision TDC  HealpixSlicer',
#  'Mean TDC_Accuracy  HealpixSlicer',
#  'Median TDC_Accuracy  HealpixSlicer',
#  'Rms TDC_Accuracy  HealpixSlicer',
#  'Mean TDC_Cadence  HealpixSlicer',
#  'Median TDC_Cadence  HealpixSlicer',
#  'Rms TDC_Cadence  HealpixSlicer',
#  'Mean TDC_Campaign  HealpixSlicer',
#  'Median TDC_Campaign  HealpixSlicer',
#  'Rms TDC_Campaign  HealpixSlicer',
#  'Mean TDC_Precision  HealpixSlicer',
#  'Median TDC_Precision  HealpixSlicer',
#  'Rms TDC_Precision  HealpixSlicer',
#  'Mean TDC_Rate  HealpixSlicer',
#  'Median TDC_Rate  HealpixSlicer',
#  'Rms TDC_Rate  HealpixSlicer',
#  'Mean TDC_Season  HealpixSlicer',
#  'Median TDC_Season  HealpixSlicer',
#  'Rms TDC_Season  HealpixSlicer',
#  'fOArea fO All visits HealpixSlicer_m',
#  'fOArea/benchmark fO All visits HealpixSlicer_m',
#  'fONv MedianNvis fO All visits HealpixSlicer_m',
#  'fONv MinNvis fO All visits HealpixSlicer_m',
#  'fONv/benchmark MedianNvis fO All visits HealpixSlicer_m',
#  'fONv/benchmark MinNvis fO All visits HealpixSlicer_m',
#  'Median Parallax Error (18k) Parallax Error @ 22.4 All visits HealpixSlicer_m',
#  '95th Percentile Parallax Error Parallax Error @ 22.4 All visits HealpixSlicer_m',
#  'Mean Parallax Error @ 22.4 All visits HealpixSlicer_m',
#  'Rms Parallax Error @ 22.4 All visits HealpixSlicer_m',
#  'Median Parallax Error @ 22.4 All visits HealpixSlicer_m',
#  'Max Parallax Error @ 22.4 All visits HealpixSlicer_m',
#  'Min Parallax Error @ 22.4 All visits HealpixSlicer_m',
#  'N(+3Sigma) Parallax Error @ 22.4 All visits HealpixSlicer_m',
#  'N(-3Sigma) Parallax Error @ 22.4 All visits HealpixSlicer_m',
#  'Parallax Error @ 22.4 All visits HealpixSlicer_m',
#  'Median Parallax Error (18k) Parallax Error @ 24.0 All visits HealpixSlicer_m',
#  '95th Percentile Parallax Error Parallax Error @ 24.0 All visits HealpixSlicer_m',
#  'Mean Parallax Error @ 24.0 All visits HealpixSlicer_m',
#  'Rms Parallax Error @ 24.0 All visits HealpixSlicer_m',
#  'Median Parallax Error @ 24.0 All visits HealpixSlicer_m',
#  'Max Parallax Error @ 24.0 All visits HealpixSlicer_m',
#  'Min Parallax Error @ 24.0 All visits HealpixSlicer_m',
#  'N(+3Sigma) Parallax Error @ 24.0 All visits HealpixSlicer_m',
#  'N(-3Sigma) Parallax Error @ 24.0 All visits HealpixSlicer_m',
#  'Parallax Error @ 24.0 All visits HealpixSlicer_m',
#  'Mean Normalized Parallax @ 22.4 All visits HealpixSlicer_m',
#  'Rms Normalized Parallax @ 22.4 All visits HealpixSlicer_m',
#  'Median Normalized Parallax @ 22.4 All visits HealpixSlicer_m',
#  'Max Normalized Parallax @ 22.4 All visits HealpixSlicer_m',
#  'Min Normalized Parallax @ 22.4 All visits HealpixSlicer_m',
#  'N(+3Sigma) Normalized Parallax @ 22.4 All visits HealpixSlicer_m',
#  'N(-3Sigma) Normalized Parallax @ 22.4 All visits HealpixSlicer_m',
#  'Normalized Parallax @ 22.4 All visits HealpixSlicer_m',
#  'Mean Normalized Parallax @ 24.0 All visits HealpixSlicer_m',
#  'Rms Normalized Parallax @ 24.0 All visits HealpixSlicer_m',
#  'Median Normalized Parallax @ 24.0 All visits HealpixSlicer_m',
#  'Max Normalized Parallax @ 24.0 All visits HealpixSlicer_m',
#  'Min Normalized Parallax @ 24.0 All visits HealpixSlicer_m',
#  'N(+3Sigma) Normalized Parallax @ 24.0 All visits HealpixSlicer_m',
#  'N(-3Sigma) Normalized Parallax @ 24.0 All visits HealpixSlicer_m',
#  'Normalized Parallax @ 24.0 All visits HealpixSlicer_m',
#  'Mean Parallax Coverage @ 22.4 All visits HealpixSlicer_m',
#  'Rms Parallax Coverage @ 22.4 All visits HealpixSlicer_m',
#  'Median Parallax Coverage @ 22.4 All visits HealpixSlicer_m',
#  'Max Parallax Coverage @ 22.4 All visits HealpixSlicer_m',
#  'Min Parallax Coverage @ 22.4 All visits HealpixSlicer_m',
#  'N(+3Sigma) Parallax Coverage @ 22.4 All visits HealpixSlicer_m',
#  'N(-3Sigma) Parallax Coverage @ 22.4 All visits HealpixSlicer_m',
#  'Parallax Coverage @ 22.4 All visits HealpixSlicer_m',
#  'Mean Parallax Coverage @ 24.0 All visits HealpixSlicer_m',
#  'Rms Parallax Coverage @ 24.0 All visits HealpixSlicer_m',
#  'Median Parallax Coverage @ 24.0 All visits HealpixSlicer_m',
#  'Max Parallax Coverage @ 24.0 All visits HealpixSlicer_m',
#  'Min Parallax Coverage @ 24.0 All visits HealpixSlicer_m',
#  'N(+3Sigma) Parallax Coverage @ 24.0 All visits HealpixSlicer_m',
#  'N(-3Sigma) Parallax Coverage @ 24.0 All visits HealpixSlicer_m',
#  'Parallax Coverage @ 24.0 All visits HealpixSlicer_m',
#  'Mean Parallax-DCR degeneracy @ 22.4 All visits HealpixSlicer_m',
#  'Rms Parallax-DCR degeneracy @ 22.4 All visits HealpixSlicer_m',
#  'Median Parallax-DCR degeneracy @ 22.4 All visits HealpixSlicer_m',
#  'Max Parallax-DCR degeneracy @ 22.4 All visits HealpixSlicer_m',
#  'Min Parallax-DCR degeneracy @ 22.4 All visits HealpixSlicer_m',
#  'N(+3Sigma) Parallax-DCR degeneracy @ 22.4 All visits HealpixSlicer_m',
#  'N(-3Sigma) Parallax-DCR degeneracy @ 22.4 All visits HealpixSlicer_m',
#  'Parallax-DCR degeneracy @ 22.4 All visits HealpixSlicer_m',
#  'Mean Parallax-DCR degeneracy @ 24.0 All visits HealpixSlicer_m',
#  'Rms Parallax-DCR degeneracy @ 24.0 All visits HealpixSlicer_m',
#  'Median Parallax-DCR degeneracy @ 24.0 All visits HealpixSlicer_m',
#  'Max Parallax-DCR degeneracy @ 24.0 All visits HealpixSlicer_m',
#  'Min Parallax-DCR degeneracy @ 24.0 All visits HealpixSlicer_m',
#  'N(+3Sigma) Parallax-DCR degeneracy @ 24.0 All visits HealpixSlicer_m',
#  'N(-3Sigma) Parallax-DCR degeneracy @ 24.0 All visits HealpixSlicer_m',
#  'Parallax-DCR degeneracy @ 24.0 All visits HealpixSlicer_m',
#  'Median Proper Motion Error (18k) Proper Motion Error @ 20.5 All visits HealpixSlicer_m',
#  '95th Percentile Proper Motion Error Proper Motion Error @ 20.5 All visits HealpixSlicer_m',
#  'Mean Proper Motion Error @ 20.5 All visits HealpixSlicer_m',
#  'Rms Proper Motion Error @ 20.5 All visits HealpixSlicer_m',
#  'Median Proper Motion Error @ 20.5 All visits HealpixSlicer_m',
#  'Max Proper Motion Error @ 20.5 All visits HealpixSlicer_m',
#  'Min Proper Motion Error @ 20.5 All visits HealpixSlicer_m',
#  'N(+3Sigma) Proper Motion Error @ 20.5 All visits HealpixSlicer_m',
#  'N(-3Sigma) Proper Motion Error @ 20.5 All visits HealpixSlicer_m',
#  'Proper Motion Error @ 20.5 All visits HealpixSlicer_m',
#  'Median Proper Motion Error (18k) Proper Motion Error @ 24.0 All visits HealpixSlicer_m',
#  '95th Percentile Proper Motion Error Proper Motion Error @ 24.0 All visits HealpixSlicer_m',
#  'Mean Proper Motion Error @ 24.0 All visits HealpixSlicer_m',
#  'Rms Proper Motion Error @ 24.0 All visits HealpixSlicer_m',
#  'Median Proper Motion Error @ 24.0 All visits HealpixSlicer_m',
#  'Max Proper Motion Error @ 24.0 All visits HealpixSlicer_m',
#  'Min Proper Motion Error @ 24.0 All visits HealpixSlicer_m',
#  'N(+3Sigma) Proper Motion Error @ 24.0 All visits HealpixSlicer_m',
#  'N(-3Sigma) Proper Motion Error @ 24.0 All visits HealpixSlicer_m',
#  'Proper Motion Error @ 24.0 All visits HealpixSlicer_m',
#  'Mean Normalized Proper Motion @ 20.5 All visits HealpixSlicer_m',
#  'Rms Normalized Proper Motion @ 20.5 All visits HealpixSlicer_m',
#  'Median Normalized Proper Motion @ 20.5 All visits HealpixSlicer_m',
#  'Max Normalized Proper Motion @ 20.5 All visits HealpixSlicer_m',
#  'Min Normalized Proper Motion @ 20.5 All visits HealpixSlicer_m',
#  'N(+3Sigma) Normalized Proper Motion @ 20.5 All visits HealpixSlicer_m',
#  'N(-3Sigma) Normalized Proper Motion @ 20.5 All visits HealpixSlicer_m',
#  'Normalized Proper Motion @ 20.5 All visits HealpixSlicer_m',
#  'Mean Normalized Proper Motion @ 24.0 All visits HealpixSlicer_m',
#  'Rms Normalized Proper Motion @ 24.0 All visits HealpixSlicer_m',
#  'Median Normalized Proper Motion @ 24.0 All visits HealpixSlicer_m',
#  'Max Normalized Proper Motion @ 24.0 All visits HealpixSlicer_m',
#  'Min Normalized Proper Motion @ 24.0 All visits HealpixSlicer_m',
#  'N(+3Sigma) Normalized Proper Motion @ 24.0 All visits HealpixSlicer_m',
#  'N(-3Sigma) Normalized Proper Motion @ 24.0 All visits HealpixSlicer_m',
#  'Normalized Proper Motion @ 24.0 All visits HealpixSlicer_m',
#  'Mean NumberOfQuickRevisits All visits HealpixSlicer_m',
#  'Rms NumberOfQuickRevisits All visits HealpixSlicer_m',
#  'Median NumberOfQuickRevisits All visits HealpixSlicer_m',
#  'Max NumberOfQuickRevisits All visits HealpixSlicer_m',
#  'Min NumberOfQuickRevisits All visits HealpixSlicer_m',
#  'N(+3Sigma) NumberOfQuickRevisits All visits HealpixSlicer_m',
#  'N(-3Sigma) NumberOfQuickRevisits All visits HealpixSlicer_m',
#  'RapidRevisits All visits HealpixSlicer_m',
#  'Mean Median Intra-Night Gap  HealpixSlicer',
#  'Rms Median Intra-Night Gap  HealpixSlicer',
#  'Median Median Intra-Night Gap  HealpixSlicer',
#  'Max Median Intra-Night Gap  HealpixSlicer',
#  'Min Median Intra-Night Gap  HealpixSlicer',
#  'N(+3Sigma) Median Intra-Night Gap  HealpixSlicer',
#  'N(-3Sigma) Median Intra-Night Gap  HealpixSlicer',
#  'Median Intra-Night Gap  HealpixSlicer',
#  'Mean Median Inter-Night Gap all bands HealpixSlicer',
#  'Rms Median Inter-Night Gap all bands HealpixSlicer',
#  'Median Median Inter-Night Gap all bands HealpixSlicer',
#  'Max Median Inter-Night Gap all bands HealpixSlicer',
#  'Min Median Inter-Night Gap all bands HealpixSlicer',
#  'N(+3Sigma) Median Inter-Night Gap all bands HealpixSlicer',
#  'N(-3Sigma) Median Inter-Night Gap all bands HealpixSlicer',
#  'Median Inter-Night Gap all bands HealpixSlicer',
#  'Mean Max Inter-Night Gap all bands HealpixSlicer',
#  'Rms Max Inter-Night Gap all bands HealpixSlicer',
#  'Median Max Inter-Night Gap all bands HealpixSlicer',
#  'Max Max Inter-Night Gap all bands HealpixSlicer',
#  'Min Max Inter-Night Gap all bands HealpixSlicer',
#  'N(+3Sigma) Max Inter-Night Gap all bands HealpixSlicer',
#  'N(-3Sigma) Max Inter-Night Gap all bands HealpixSlicer',
#  'Max Inter-Night Gap all bands HealpixSlicer',
#  'Mean Median Season Length all bands HealpixSlicer',
#  'Rms Median Season Length all bands HealpixSlicer',
#  'Median Median Season Length all bands HealpixSlicer',
#  'Max Median Season Length all bands HealpixSlicer',
#  'Min Median Season Length all bands HealpixSlicer',
#  'N(+3Sigma) Median Season Length all bands HealpixSlicer',
#  'N(-3Sigma) Median Season Length all bands HealpixSlicer',
#  'Median Season Length all bands HealpixSlicer',
#  'Mean Min airmass all bands HealpixSlicer',
#  'Rms Min airmass all bands HealpixSlicer',
#  'Median Min airmass all bands HealpixSlicer',
#  'Max Min airmass all bands HealpixSlicer',
#  'Min Min airmass all bands HealpixSlicer',
#  'N(+3Sigma) Min airmass all bands HealpixSlicer',
#  'N(-3Sigma) Min airmass all bands HealpixSlicer',
#  'Min airmass all bands HealpixSlicer',
#  'Mean Median airmass all bands HealpixSlicer',
#  'Rms Median airmass all bands HealpixSlicer',
#  'Median Median airmass all bands HealpixSlicer',
#  'Max Median airmass all bands HealpixSlicer',
#  'Min Median airmass all bands HealpixSlicer',
#  'N(+3Sigma) Median airmass all bands HealpixSlicer',
#  'N(-3Sigma) Median airmass all bands HealpixSlicer',
#  'Median airmass all bands HealpixSlicer',
#  'Mean Max airmass all bands HealpixSlicer',
#  'Rms Max airmass all bands HealpixSlicer',
#  'Median Max airmass all bands HealpixSlicer',
#  'Max Max airmass all bands HealpixSlicer',
#  'Min Max airmass all bands HealpixSlicer',
#  'N(+3Sigma) Max airmass all bands HealpixSlicer',
#  'N(-3Sigma) Max airmass all bands HealpixSlicer',
#  'Max airmass all bands HealpixSlicer',
#  'Mean Min normairmass all bands HealpixSlicer',
#  'Rms Min normairmass all bands HealpixSlicer',
#  'Median Min normairmass all bands HealpixSlicer',
#  'Max Min normairmass all bands HealpixSlicer',
#  'Min Min normairmass all bands HealpixSlicer',
#  'N(+3Sigma) Min normairmass all bands HealpixSlicer',
#  'N(-3Sigma) Min normairmass all bands HealpixSlicer',
#  'Min normairmass all bands HealpixSlicer',
#  'Mean Median normairmass all bands HealpixSlicer',
#  'Rms Median normairmass all bands HealpixSlicer',
#  'Median Median normairmass all bands HealpixSlicer',
#  'Max Median normairmass all bands HealpixSlicer',
#  'Min Median normairmass all bands HealpixSlicer',
#  'N(+3Sigma) Median normairmass all bands HealpixSlicer',
#  'N(-3Sigma) Median normairmass all bands HealpixSlicer',
#  'Median normairmass all bands HealpixSlicer',
#  'Mean Max normairmass all bands HealpixSlicer',
#  'Rms Max normairmass all bands HealpixSlicer',
#  'Median Max normairmass all bands HealpixSlicer',
#  'Max Max normairmass all bands HealpixSlicer',
#  'Min Max normairmass all bands HealpixSlicer',
#  'N(+3Sigma) Max normairmass all bands HealpixSlicer',
#  'N(-3Sigma) Max normairmass all bands HealpixSlicer',
#  'Max normairmass all bands HealpixSlicer',
#  'Mean Min seeingEff all bands HealpixSlicer',
#  'Rms Min seeingEff all bands HealpixSlicer',
#  'Median Min seeingEff all bands HealpixSlicer',
#  'Max Min seeingEff all bands HealpixSlicer',
#  'Min Min seeingEff all bands HealpixSlicer',
#  'N(+3Sigma) Min seeingEff all bands HealpixSlicer',
#  'N(-3Sigma) Min seeingEff all bands HealpixSlicer',
#  'Min seeingEff all bands HealpixSlicer',
#  'Mean Median seeingEff all bands HealpixSlicer',
#  'Rms Median seeingEff all bands HealpixSlicer',
#  'Median Median seeingEff all bands HealpixSlicer',
#  'Max Median seeingEff all bands HealpixSlicer',
#  'Min Median seeingEff all bands HealpixSlicer',
#  'N(+3Sigma) Median seeingEff all bands HealpixSlicer',
#  'N(-3Sigma) Median seeingEff all bands HealpixSlicer',
#  'Median seeingEff all bands HealpixSlicer',
#  'Mean Max seeingEff all bands HealpixSlicer',
#  'Rms Max seeingEff all bands HealpixSlicer',
#  'Median Max seeingEff all bands HealpixSlicer',
#  'Max Max seeingEff all bands HealpixSlicer',
#  'Min Max seeingEff all bands HealpixSlicer',
#  'N(+3Sigma) Max seeingEff all bands HealpixSlicer',
#  'N(-3Sigma) Max seeingEff all bands HealpixSlicer',
#  'Max seeingEff all bands HealpixSlicer',
#  'Mean Min skyBrightness all bands HealpixSlicer',
#  'Rms Min skyBrightness all bands HealpixSlicer',
#  'Median Min skyBrightness all bands HealpixSlicer',
#  'Max Min skyBrightness all bands HealpixSlicer',
#  'Min Min skyBrightness all bands HealpixSlicer',
#  'N(+3Sigma) Min skyBrightness all bands HealpixSlicer',
#  'N(-3Sigma) Min skyBrightness all bands HealpixSlicer',
#  'Min skyBrightness all bands HealpixSlicer',
#  'Mean Median skyBrightness all bands HealpixSlicer',
#  'Rms Median skyBrightness all bands HealpixSlicer',
#  'Median Median skyBrightness all bands HealpixSlicer',
#  'Max Median skyBrightness all bands HealpixSlicer',
#  'Min Median skyBrightness all bands HealpixSlicer',
#  'N(+3Sigma) Median skyBrightness all bands HealpixSlicer',
#  'N(-3Sigma) Median skyBrightness all bands HealpixSlicer',
#  'Median skyBrightness all bands HealpixSlicer',
#  'Mean Max skyBrightness all bands HealpixSlicer',
#  'Rms Max skyBrightness all bands HealpixSlicer',
#  'Median Max skyBrightness all bands HealpixSlicer',
#  'Max Max skyBrightness all bands HealpixSlicer',
#  'Min Max skyBrightness all bands HealpixSlicer',
#  'N(+3Sigma) Max skyBrightness all bands HealpixSlicer',
#  'N(-3Sigma) Max skyBrightness all bands HealpixSlicer',
#  'Max skyBrightness all bands HealpixSlicer',
#  'Mean Min fiveSigmaDepth all bands HealpixSlicer',
#  'Rms Min fiveSigmaDepth all bands HealpixSlicer',
#  'Median Min fiveSigmaDepth all bands HealpixSlicer',
#  'Max Min fiveSigmaDepth all bands HealpixSlicer',
#  'Min Min fiveSigmaDepth all bands HealpixSlicer',
#  'N(+3Sigma) Min fiveSigmaDepth all bands HealpixSlicer',
#  'N(-3Sigma) Min fiveSigmaDepth all bands HealpixSlicer',
#  'Min fiveSigmaDepth all bands HealpixSlicer',
#  'Mean Median fiveSigmaDepth all bands HealpixSlicer',
#  'Rms Median fiveSigmaDepth all bands HealpixSlicer',
#  'Median Median fiveSigmaDepth all bands HealpixSlicer',
#  'Max Median fiveSigmaDepth all bands HealpixSlicer',
#  'Min Median fiveSigmaDepth all bands HealpixSlicer',
#  'N(+3Sigma) Median fiveSigmaDepth all bands HealpixSlicer',
#  'N(-3Sigma) Median fiveSigmaDepth all bands HealpixSlicer',
#  'Median fiveSigmaDepth all bands HealpixSlicer',
#  'Mean Max fiveSigmaDepth all bands HealpixSlicer',
#  'Rms Max fiveSigmaDepth all bands HealpixSlicer',
#  'Median Max fiveSigmaDepth all bands HealpixSlicer',
#  'Max Max fiveSigmaDepth all bands HealpixSlicer',
#  'Min Max fiveSigmaDepth all bands HealpixSlicer',
#  'N(+3Sigma) Max fiveSigmaDepth all bands HealpixSlicer',
#  'N(-3Sigma) Max fiveSigmaDepth all bands HealpixSlicer',
#  'Max fiveSigmaDepth all bands HealpixSlicer',
#  'Mean Min HA all bands HealpixSlicer',
#  'Rms Min HA all bands HealpixSlicer',
#  'Median Min HA all bands HealpixSlicer',
#  'Max Min HA all bands HealpixSlicer',
#  'Min Min HA all bands HealpixSlicer',
#  'N(+3Sigma) Min HA all bands HealpixSlicer',
#  'N(-3Sigma) Min HA all bands HealpixSlicer',
#  'Min HA all bands HealpixSlicer',
#  'Mean Median HA all bands HealpixSlicer',
#  'Rms Median HA all bands HealpixSlicer',
#  'Median Median HA all bands HealpixSlicer',
#  'Max Median HA all bands HealpixSlicer',
#  'Min Median HA all bands HealpixSlicer',
#  'N(+3Sigma) Median HA all bands HealpixSlicer',
#  'N(-3Sigma) Median HA all bands HealpixSlicer',
#  'Median HA all bands HealpixSlicer',
#  'Mean Max HA all bands HealpixSlicer',
#  'Rms Max HA all bands HealpixSlicer',
#  'Median Max HA all bands HealpixSlicer',
#  'Max Max HA all bands HealpixSlicer',
#  'Min Max HA all bands HealpixSlicer',
#  'N(+3Sigma) Max HA all bands HealpixSlicer',
#  'N(-3Sigma) Max HA all bands HealpixSlicer',
#  'Max HA all bands HealpixSlicer',
#  'Mean Min moonDistance all bands HealpixSlicer',
#  'Rms Min moonDistance all bands HealpixSlicer',
#  'Median Min moonDistance all bands HealpixSlicer',
#  'Max Min moonDistance all bands HealpixSlicer',
#  'Min Min moonDistance all bands HealpixSlicer',
#  'N(+3Sigma) Min moonDistance all bands HealpixSlicer',
#  'N(-3Sigma) Min moonDistance all bands HealpixSlicer',
#  'Min moonDistance all bands HealpixSlicer',
#  'Mean Median moonDistance all bands HealpixSlicer',
#  'Rms Median moonDistance all bands HealpixSlicer',
#  'Median Median moonDistance all bands HealpixSlicer',
#  'Max Median moonDistance all bands HealpixSlicer',
#  'Min Median moonDistance all bands HealpixSlicer',
#  'N(+3Sigma) Median moonDistance all bands HealpixSlicer',
#  'N(-3Sigma) Median moonDistance all bands HealpixSlicer',
#  'Median moonDistance all bands HealpixSlicer',
#  'Mean Max moonDistance all bands HealpixSlicer',
#  'Rms Max moonDistance all bands HealpixSlicer',
#  'Median Max moonDistance all bands HealpixSlicer',
#  'Max Max moonDistance all bands HealpixSlicer',
#  'Min Max moonDistance all bands HealpixSlicer',
#  'N(+3Sigma) Max moonDistance all bands HealpixSlicer',
#  'N(-3Sigma) Max moonDistance all bands HealpixSlicer',
#  'Max moonDistance all bands HealpixSlicer',
#  'Mean Min solarElong all bands HealpixSlicer',
#  'Rms Min solarElong all bands HealpixSlicer',
#  'Median Min solarElong all bands HealpixSlicer',
#  'Max Min solarElong all bands HealpixSlicer',
#  'Min Min solarElong all bands HealpixSlicer',
#  'N(+3Sigma) Min solarElong all bands HealpixSlicer',
#  'N(-3Sigma) Min solarElong all bands HealpixSlicer',
#  'Min solarElong all bands HealpixSlicer',
#  'Mean Median solarElong all bands HealpixSlicer',
#  'Rms Median solarElong all bands HealpixSlicer',
#  'Median Median solarElong all bands HealpixSlicer',
#  'Max Median solarElong all bands HealpixSlicer',
#  'Min Median solarElong all bands HealpixSlicer',
#  'N(+3Sigma) Median solarElong all bands HealpixSlicer',
#  'N(-3Sigma) Median solarElong all bands HealpixSlicer',
#  'Median solarElong all bands HealpixSlicer',
#  'Mean Max solarElong all bands HealpixSlicer',
#  'Rms Max solarElong all bands HealpixSlicer',
#  'Median Max solarElong all bands HealpixSlicer',
#  'Max Max solarElong all bands HealpixSlicer',
#  'Min Max solarElong all bands HealpixSlicer',
#  'N(+3Sigma) Max solarElong all bands HealpixSlicer',
#  'N(-3Sigma) Max solarElong all bands HealpixSlicer',
#  'Max solarElong all bands HealpixSlicer',
#  'Mean AngleMean rotSkyPos all bands HealpixSlicer',
#  'Rms AngleMean rotSkyPos all bands HealpixSlicer',
#  'Median AngleMean rotSkyPos all bands HealpixSlicer',
#  'Max AngleMean rotSkyPos all bands HealpixSlicer',
#  'Min AngleMean rotSkyPos all bands HealpixSlicer',
#  'N(+3Sigma) AngleMean rotSkyPos all bands HealpixSlicer',
#  'N(-3Sigma) AngleMean rotSkyPos all bands HealpixSlicer',
#  'AngleMean rotSkyPos all bands HealpixSlicer',
#  'Mean AngleRange rotSkyPos all bands HealpixSlicer',
#  'Rms AngleRange rotSkyPos all bands HealpixSlicer',
#  'Median AngleRange rotSkyPos all bands HealpixSlicer',
#  'Max AngleRange rotSkyPos all bands HealpixSlicer',
#  'Min AngleRange rotSkyPos all bands HealpixSlicer',
#  'N(+3Sigma) AngleRange rotSkyPos all bands HealpixSlicer',
#  'N(-3Sigma) AngleRange rotSkyPos all bands HealpixSlicer',
#  'AngleRange rotSkyPos all bands HealpixSlicer',
#  'Mean AngleRms rotSkyPos all bands HealpixSlicer',
#  'Rms AngleRms rotSkyPos all bands HealpixSlicer',
#  'Median AngleRms rotSkyPos all bands HealpixSlicer',
#  'Max AngleRms rotSkyPos all bands HealpixSlicer',
#  'Min AngleRms rotSkyPos all bands HealpixSlicer',
#  'N(+3Sigma) AngleRms rotSkyPos all bands HealpixSlicer',
#  'N(-3Sigma) AngleRms rotSkyPos all bands HealpixSlicer',
#  'AngleRms rotSkyPos all bands HealpixSlicer',
#  'Mean NVisits all bands HealpixSlicer',
#  'Rms NVisits all bands HealpixSlicer',
#  'Median NVisits all bands HealpixSlicer',
#  'Max NVisits all bands HealpixSlicer',
#  'Min NVisits all bands HealpixSlicer',
#  'N(+3Sigma) NVisits all bands HealpixSlicer',
#  'N(-3Sigma) NVisits all bands HealpixSlicer',
#  'NVisits all bands HealpixSlicer',
#  'Mean Normalized Teff all bands HealpixSlicer',
#  'Rms Normalized Teff all bands HealpixSlicer',
#  'Median Normalized Teff all bands HealpixSlicer',
#  'Max Normalized Teff all bands HealpixSlicer',
#  'Min Normalized Teff all bands HealpixSlicer',
#  'N(+3Sigma) Normalized Teff all bands HealpixSlicer',
#  'N(-3Sigma) Normalized Teff all bands HealpixSlicer',
#  'Normalized Teff all bands HealpixSlicer',
#  'Mean airmass all bands',
#  'Median airmass all bands',
#  'Min airmass all bands',
#  'Max airmass all bands',
#  'Rms airmass all bands',
#  'N(+3Sigma) airmass all bands',
#  'N(-3Sigma) airmass all bands',
#  '25th%ile airmass all bands',
#  '75th%ile airmass all bands',
#  'Count airmass all bands',
#  'Mean normairmass all bands',
#  'Median normairmass all bands',
#  'Min normairmass all bands',
#  'Max normairmass all bands',
#  'Rms normairmass all bands',
#  'N(+3Sigma) normairmass all bands',
#  'N(-3Sigma) normairmass all bands',
#  '25th%ile normairmass all bands',
#  '75th%ile normairmass all bands',
#  'Count normairmass all bands',
#  'Mean seeingEff all bands',
#  'Median seeingEff all bands',
#  'Min seeingEff all bands',
#  'Max seeingEff all bands',
#  'Rms seeingEff all bands',
#  'N(+3Sigma) seeingEff all bands',
#  'N(-3Sigma) seeingEff all bands',
#  '25th%ile seeingEff all bands',
#  '75th%ile seeingEff all bands',
#  'Count seeingEff all bands',
#  'Mean skyBrightness all bands',
#  'Median skyBrightness all bands',
#  'Min skyBrightness all bands',
#  'Max skyBrightness all bands',
#  'Rms skyBrightness all bands',
#  'N(+3Sigma) skyBrightness all bands',
#  'N(-3Sigma) skyBrightness all bands',
#  '25th%ile skyBrightness all bands',
#  '75th%ile skyBrightness all bands',
#  'Count skyBrightness all bands',
#  'Mean fiveSigmaDepth all bands',
#  'Median fiveSigmaDepth all bands',
#  'Min fiveSigmaDepth all bands',
#  'Max fiveSigmaDepth all bands',
#  'Rms fiveSigmaDepth all bands',
#  'N(+3Sigma) fiveSigmaDepth all bands',
#  'N(-3Sigma) fiveSigmaDepth all bands',
#  '25th%ile fiveSigmaDepth all bands',
#  '75th%ile fiveSigmaDepth all bands',
#  'Count fiveSigmaDepth all bands',
#  'Mean HA all bands',
#  'Median HA all bands',
#  'Min HA all bands',
#  'Max HA all bands',
#  'Rms HA all bands',
#  'N(+3Sigma) HA all bands',
#  'N(-3Sigma) HA all bands',
#  '25th%ile HA all bands',
#  '75th%ile HA all bands',
#  'Count HA all bands',
#  'Mean moonDistance all bands',
#  'Median moonDistance all bands',
#  'Min moonDistance all bands',
#  'Max moonDistance all bands',
#  'Rms moonDistance all bands',
#  'N(+3Sigma) moonDistance all bands',
#  'N(-3Sigma) moonDistance all bands',
#  '25th%ile moonDistance all bands',
#  '75th%ile moonDistance all bands',
#  'Count moonDistance all bands',
#  'Mean solarElong all bands',
#  'Median solarElong all bands',
#  'Min solarElong all bands',
#  'Max solarElong all bands',
#  'Rms solarElong all bands',
#  'N(+3Sigma) solarElong all bands',
#  'N(-3Sigma) solarElong all bands',
#  '25th%ile solarElong all bands',
#  '75th%ile solarElong all bands',
#  'Count solarElong all bands',
#  'MeanAngle rotSkyPos all bands',
#  'RmsAngle rotSkyPos all bands',
#  'FullRangeAngle rotSkyPos all bands',
#  'Min rotSkyPos all bands',
#  'Max rotSkyPos all bands',
#  'Total Teff all bands',
#  'Normalized Teff all bands',
#  'Nvisits All props',
#  'Fraction of total Nvisits All props',
#  'Slew Count All visits',
#  'Mean slewTime All visits',
#  'Median slewTime All visits',
#  'Min slewTime All visits',
#  'Max slewTime All visits',
#  'OpenShutterFraction All visits',
#  'CountUnique night All visits',
#  'FullRange night All visits',
#  'Filter Changes Whole Survey',
#  'Minimum time between filter changes (minutes) Whole Survey',
#  'Number of filter changes faster than <10.0 minutes Whole Survey',
#  'Number of filter changes faster than <20.0 minutes Whole Survey',
#  'Max number of filter changes within 10.0 minutes Whole Survey',
#  'Max number of filter changes within 20.0 minutes Whole Survey',
#  'Mean Nvisits All props OneDSlicer',
#  'Rms Nvisits All props OneDSlicer',
#  'Median Nvisits All props OneDSlicer',
#  'Max Nvisits All props OneDSlicer',
#  'Min Nvisits All props OneDSlicer',
#  'N(+3Sigma) Nvisits All props OneDSlicer',
#  'N(-3Sigma) Nvisits All props OneDSlicer',
#  'Nvisits All props OneDSlicer',
#  'Mean OpenShutterFraction Per night OneDSlicer',
#  'Rms OpenShutterFraction Per night OneDSlicer',
#  'Median OpenShutterFraction Per night OneDSlicer',
#  'Max OpenShutterFraction Per night OneDSlicer',
#  'Min OpenShutterFraction Per night OneDSlicer',
#  'N(+3Sigma) OpenShutterFraction Per night OneDSlicer',
#  'N(-3Sigma) OpenShutterFraction Per night OneDSlicer',
#  'OpenShutterFraction Per night OneDSlicer',
#  'Mean Filter Changes Per Night OneDSlicer',
#  'Rms Filter Changes Per Night OneDSlicer',
#  'Median Filter Changes Per Night OneDSlicer',
#  'Max Filter Changes Per Night OneDSlicer',
#  'Min Filter Changes Per Night OneDSlicer',
#  'N(+3Sigma) Filter Changes Per Night OneDSlicer',
#  'N(-3Sigma) Filter Changes Per Night OneDSlicer',
#  'Filter Changes Per Night OneDSlicer',
#  'Mean Minimum time between filter changes (minutes) Per Night OneDSlicer',
#  'Rms Minimum time between filter changes (minutes) Per Night OneDSlicer',
#  'Median Minimum time between filter changes (minutes) Per Night OneDSlicer',
#  'Max Minimum time between filter changes (minutes) Per Night OneDSlicer',
#  'Min Minimum time between filter changes (minutes) Per Night OneDSlicer',
#  'N(+3Sigma) Minimum time between filter changes (minutes) Per Night OneDSlicer',
#  'N(-3Sigma) Minimum time between filter changes (minutes) Per Night OneDSlicer',
#  'Minimum time between filter changes (minutes) Per Night OneDSlicer',
#  'Mean Number of filter changes faster than <10.0 minutes Per Night OneDSlicer',
#  'Rms Number of filter changes faster than <10.0 minutes Per Night OneDSlicer',
#  'Median Number of filter changes faster than <10.0 minutes Per Night OneDSlicer',
#  'Max Number of filter changes faster than <10.0 minutes Per Night OneDSlicer',
#  'Min Number of filter changes faster than <10.0 minutes Per Night OneDSlicer',
#  'N(+3Sigma) Number of filter changes faster than <10.0 minutes Per Night OneDSlicer',
#  'N(-3Sigma) Number of filter changes faster than <10.0 minutes Per Night OneDSlicer',
#  'Number of filter changes faster than <10.0 minutes Per Night OneDSlicer',
#  'Mean Number of filter changes faster than <20.0 minutes Per Night OneDSlicer',
#  'Rms Number of filter changes faster than <20.0 minutes Per Night OneDSlicer',
#  'Median Number of filter changes faster than <20.0 minutes Per Night OneDSlicer',
#  'Max Number of filter changes faster than <20.0 minutes Per Night OneDSlicer',
#  'Min Number of filter changes faster than <20.0 minutes Per Night OneDSlicer',
#  'N(+3Sigma) Number of filter changes faster than <20.0 minutes Per Night OneDSlicer',
#  'N(-3Sigma) Number of filter changes faster than <20.0 minutes Per Night OneDSlicer',
#  'Number of filter changes faster than <20.0 minutes Per Night OneDSlicer',
#  'Mean Max number of filter changes within 10.0 minutes Per Night OneDSlicer',
#  'Rms Max number of filter changes within 10.0 minutes Per Night OneDSlicer',
#  'Median Max number of filter changes within 10.0 minutes Per Night OneDSlicer',
#  'Max Max number of filter changes within 10.0 minutes Per Night OneDSlicer',
#  'Min Max number of filter changes within 10.0 minutes Per Night OneDSlicer',
#  'N(+3Sigma) Max number of filter changes within 10.0 minutes Per Night OneDSlicer',
#  'N(-3Sigma) Max number of filter changes within 10.0 minutes Per Night OneDSlicer',
#  'Max number of filter changes within 10.0 minutes Per Night OneDSlicer',
#  'Mean Max number of filter changes within 20.0 minutes Per Night OneDSlicer',
#  'Rms Max number of filter changes within 20.0 minutes Per Night OneDSlicer',
#  'Median Max number of filter changes within 20.0 minutes Per Night OneDSlicer',
#  'Max Max number of filter changes within 20.0 minutes Per Night OneDSlicer',
#  'Min Max number of filter changes within 20.0 minutes Per Night OneDSlicer',
#  'N(+3Sigma) Max number of filter changes within 20.0 minutes Per Night OneDSlicer',
#  'N(-3Sigma) Max number of filter changes within 20.0 minutes Per Night OneDSlicer',
#  'Max number of filter changes within 20.0 minutes Per Night OneDSlicer',
#  'Mean Nvisits Other OneDSlicer',
#  'Rms Nvisits Other OneDSlicer',
#  'Median Nvisits Other OneDSlicer',
#  'Max Nvisits Other OneDSlicer',
#  'Min Nvisits Other OneDSlicer',
#  'N(+3Sigma) Nvisits Other OneDSlicer',
#  'N(-3Sigma) Nvisits Other OneDSlicer',
#  'Nvisits Other OneDSlicer',
#  'Nvisits Other',
#  'Fraction of total Nvisits Other',
#  'Mean Median Inter-Night Gap g band HealpixSlicer',
#  'Rms Median Inter-Night Gap g band HealpixSlicer',
#  'Median Median Inter-Night Gap g band HealpixSlicer',
#  'Max Median Inter-Night Gap g band HealpixSlicer',
#  'Min Median Inter-Night Gap g band HealpixSlicer',
#  'N(+3Sigma) Median Inter-Night Gap g band HealpixSlicer',
#  'N(-3Sigma) Median Inter-Night Gap g band HealpixSlicer',
#  'Median Inter-Night Gap g band HealpixSlicer',
#  'Mean Max Inter-Night Gap g band HealpixSlicer',
#  'Rms Max Inter-Night Gap g band HealpixSlicer',
#  'Median Max Inter-Night Gap g band HealpixSlicer',
#  'Max Max Inter-Night Gap g band HealpixSlicer',
#  'Min Max Inter-Night Gap g band HealpixSlicer',
#  'N(+3Sigma) Max Inter-Night Gap g band HealpixSlicer',
#  'N(-3Sigma) Max Inter-Night Gap g band HealpixSlicer',
#  'Max Inter-Night Gap g band HealpixSlicer',
#  'Mean Median Season Length g band HealpixSlicer',
#  'Rms Median Season Length g band HealpixSlicer',
#  'Median Median Season Length g band HealpixSlicer',
#  'Max Median Season Length g band HealpixSlicer',
#  'Min Median Season Length g band HealpixSlicer',
#  'N(+3Sigma) Median Season Length g band HealpixSlicer',
#  'N(-3Sigma) Median Season Length g band HealpixSlicer',
#  'Median Season Length g band HealpixSlicer',
#  'Mean Min airmass g band HealpixSlicer',
#  'Rms Min airmass g band HealpixSlicer',
#  'Median Min airmass g band HealpixSlicer',
#  'Max Min airmass g band HealpixSlicer',
#  'Min Min airmass g band HealpixSlicer',
#  'N(+3Sigma) Min airmass g band HealpixSlicer',
#  'N(-3Sigma) Min airmass g band HealpixSlicer',
#  'Min airmass g band HealpixSlicer',
#  'Mean Median airmass g band HealpixSlicer',
#  'Rms Median airmass g band HealpixSlicer',
#  'Median Median airmass g band HealpixSlicer',
#  'Max Median airmass g band HealpixSlicer',
#  'Min Median airmass g band HealpixSlicer',
#  ...]
